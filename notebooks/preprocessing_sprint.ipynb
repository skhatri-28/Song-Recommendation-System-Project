# %%
import numpy as np
import pandas as pd
import sklearn.preprocessing as pp
import sklearn.impute as impute

# %%
reldir = '../datasets/'

# %%
df = pd.read_pickle(reldir + 'msd_tastes_merged.csv', compression='zip')
df_msd = pd.read_pickle(reldir + 'msd.csv', compression='zip')

# %%
# split into numerical and object
df_num = df_msd.select_dtypes(exclude='object')
df_obj = df_msd.select_dtypes(include='object')

# %%
df_id = df_msd[[col for col in df_msd if col.endswith('id')]]

# %%
# drop all cols ending in id
id_cols = [col for col in df_num if col.endswith('id')]
df_num = df_num[[col for col in df_num if not id_cols.__contains__(col)]]

# %%
# drop all cols in df_num w/ std = 0
num_feat_std0 = list(df_num.describe().loc['std'].where(lambda x : x <= 0).dropna().index)
df_num = df_num[[col for col in df_num if not num_feat_std0.__contains__(col)]]

# %%
# drop useless columns
df_num = df_num.drop([
    'analysis_songs_end_of_fade_in',
    'metadata_songs_artist_latitude',
    'metadata_songs_artist_longitude',
    'analysis_songs_start_of_fade_out',
    'analysis_songs_loudness'
], axis=1)

# %%
# split into categorical numeric vs true numeric values
num_cat = [
    'analysis_songs_key',
    'analysis_songs_key_confidence',
    'analysis_songs_mode',
    'analysis_songs_mode_confidence',
    'analysis_songs_tempo',
    'analysis_songs_time_signature',
    'analysis_songs_time_signature_confidence',
    'musicbrainz_songs_year'
]

df_num_cat = df_num[num_cat]
df_num = df_num[[col for col in df_num if not num_cat.__contains__(col)]]

# %%
df_num_copy = df_num.copy()

# %%
pd.isnull(df_num_copy).sum().where(lambda x : x > 0).dropna()
# Out:
# metadata_songs_artist_familiarity       4.0
# metadata_songs_song_hotttnesss       4352.0
# dtype: float64

# %%
# Need to do imputations on NaN
df_num_cat['song_hotttnesss_indicator_missing'] = np.where(df_num_copy['metadata_songs_song_hotttnesss'].isna(), True, False)
df_num_cat['metadata_songs_artist_familiarity_missing'] = np.where(df_num_copy['metadata_songs_artist_familiarity'].isna(), True, False)
mean_imputer = impute.SimpleImputer(missing_values=np.nan)
df_num_copy = pd.DataFrame(mean_imputer.fit_transform(df_num_copy))
df_num_copy.columns = df_num.columns
df_num_copy.index = df_num.index

# %%
# Apply RobustScaler to song artist hotness to normalize the data.
# RobustScaler is robust to outliers
rb = pp.RobustScaler()
df_num_copy = pd.DataFrame(rb.fit_transform(df_num_copy))

# scaler = pp.MinMaxScaler()
# df_num_copy = pd.DataFrame(scaler.fit_transform(df_num_copy))
df_num_copy.columns = df_num.columns
df_num_copy.index = df_num.index

# %%
df_num = df_num_copy

# %%
le = pp.LabelEncoder()

# %%
# Bin year by decade and encode with LabelEncoder
df_num_cat['years_binned'] = pd.cut(df_num_cat['musicbrainz_songs_year'], bins=[0, 1970, 1980, 1990, 2000, 2010, 2020], include_lowest=True)
df_num_cat['years_binned'] = le.fit_transform(df_num_cat['years_binned'])
years_enc = le.classes_

# %%
# Perform equal width binning based on decile
df_num_cat['tempo_binned'] = pd.qcut(df_num_cat['analysis_songs_tempo'], q=10)
df_num_cat['tempo_binned'] = le.fit_transform(df_num_cat['tempo_binned'])
tempo_enc = le.classes_

# %%
columns = [df_num.columns, df_num_cat.columns]
columns
# Out:
# [Index(['analysis_songs_duration', 'metadata_songs_artist_familiarity',
#         'metadata_songs_artist_hotttnesss', 'metadata_songs_song_hotttnesss'],
#        dtype='object'),
#  Index(['analysis_songs_key', 'analysis_songs_key_confidence',
#         'analysis_songs_mode', 'analysis_songs_mode_confidence',
#         'analysis_songs_tempo', 'analysis_songs_time_signature',
#         'analysis_songs_time_signature_confidence', 'musicbrainz_songs_year',
#         'song_hotttnesss_indicator_missing',
#         'metadata_songs_artist_familiarity_missing', 'years_binned',
#         'tempo_binned'],
#        dtype='object')]

# %%
df_m = pd.DataFrame()
for col in df_id:
    df_m[col] = df_id[col]
for col in df_num_cat:
    df_m[col] = df_num_cat[col]
for col in df_num:
    df_m[col] = df_num[col]

# %%
df_m
# Out:
#      analysis_songs_track_id  metadata_songs_artist_7digitalid  \
# 0         TRARRZU128F4253CA2                             16971
# 1         TRARRJL128F92DED0E                             92108
# 2         TRARRUZ128F9307C57                              1701
# 3         TRARRWA128F42A0195                             92184
# 4         TRARRPG12903CD1DE9                            278655
# ...                      ...                               ...
# 9995      TRBBWSE128F9313963                            327831
# 9996      TRBBWDJ128F42595D5                               106
# 9997      TRBBWNS128F426F760                            197865
# 9998      TRBBWIP128F4287400                            180187
# 9999      TRBBWKS128F424E84A                             68006
#
#      metadata_songs_artist_id            metadata_songs_artist_mbid  \
# 0          AREJXK41187B9A4ACC  c43bb0d6-94d7-410f-80fb-e5a243b18d23
# 1          AR2XRFQ1187FB417FE  a69cd724-2f57-4ed0-bfed-ba20401eb84c
# 2          ARODOO01187FB44F4A  60bd8a1c-c093-4849-8f28-08101ca059b1
# 3          ARJGW911187FB586CA  44b5b950-2ae2-403a-8c67-82d8fc72033d
# 4          AR9HQ6Y1187FB3C2CB  0e6524bd-6641-46a6-bce5-96f06c19aa46
# ...                       ...                                   ...
# 9995       AR9UPVA1187FB51260  5d8f51d7-0531-46a4-b604-3e758ff58283
# 9996       ARUJ5A41187FB3F5F1  a3cb23fc-acd3-4ce0-8f36-1e5aa6a18432
# 9997       ARWC3XN1187B9A8D82  bccf45e7-bca3-45c7-ae7b-c8b0ee7e7fa3
# 9998       AR0GGKI1187FB391D5  f930ba6a-a87f-44d6-abe5-0c172772d9e4
# 9999       ARQXGWX11F50C49BC7  5e814d09-9d00-4e43-9a0d-61c73b4ed380
#
#       metadata_songs_artist_playmeid  metadata_songs_release_7digitalid  \
# 0                               2676                             275907
# 1                               5772                             382807
# 2                              20540                             490659
# 3                                 -1                             116616
# 4                                 -1                             767122
# ...                              ...                                ...
# 9995                              -1                             453635
# 9996                            1636                             278645
# 9997                          168634                             258315
# 9998                              -1                             219488
# 9999                           51224                             196895
#
#      metadata_songs_song_id  metadata_songs_track_7digitalid  \
# 0        SOGSMXL12A81C23D88                          3073568
# 1        SOMBCOW12AAF3B229F                          4249244
# 2        SOEYIHF12AB017B5F4                          5436063
# 3        SODJYEC12A8C13D757                          1199928
# 4        SOGSOUE12A58A76443                          8493899
# ...                     ...                              ...
# 9995     SOWJQRH12AB0186761                          5034564
# 9996     SOIFMVY12A8AE467B1                          3103042
# 9997     SOGVDLQ12A58A7E3C5                          2868556
# 9998     SOVVGSH12A8C14085F                          2394328
# 9999     SOPNUVB12A8C13627D                          2139729
#
#       analysis_songs_key  analysis_songs_key_confidence  ...  \
# 0                      0                          0.591  ...
# 1                      1                          0.429  ...
# 2                      3                          0.000  ...
# 3                      7                          0.380  ...
# 4                     10                          0.551  ...
# ...                  ...                            ...  ...
# 9995                   7                          0.444  ...
# 9996                   9                          0.756  ...
# 9997                   7                          0.180  ...
# 9998                   8                          0.042  ...
# 9999                   6                          0.608  ...
#
#       analysis_songs_time_signature_confidence  musicbrainz_songs_year  \
# 0                                        0.372                    2008
# 1                                        0.533                    2004
# 2                                        0.000                       0
# 3                                        0.369                    2007
# 4                                        1.000                       0
# ...                                        ...                     ...
# 9995                                     0.243                       0
# 9996                                     0.536                    1981
# 9997                                     0.307                    2007
# 9998                                     0.484                    2007
# 9999                                     0.345                       0
#
#       song_hotttnesss_indicator_missing  \
# 0                                 False
# 1                                 False
# 2                                  True
# 3                                  True
# 4                                  True
# ...                                 ...
# 9995                               True
# 9996                               True
# 9997                              False
# 9998                              False
# 9999                               True
#
#       metadata_songs_artist_familiarity_missing  years_binned  tempo_binned  \
# 0                                         False             4             5
# 1                                         False             4             0
# 2                                         False             0             0
# 3                                         False             4             0
# 4                                         False             0             5
# ...                                         ...           ...           ...
# 9995                                      False             0             7
# 9996                                      False             2             2
# 9997                                      False             4             1
# 9998                                      False             4             8
# 9999                                      False             0             6
#
#       analysis_songs_duration  metadata_songs_artist_familiarity  \
# 0                   -0.740644                          -0.031380
# 1                    0.298340                           0.315424
# 2                   -1.445363                          -0.688767
# 3                   -0.592255                           0.238264
# 4                   -0.229873                          -0.980535
# ...                       ...                                ...
# 9995                 0.140579                          -2.569412
# 9996                -0.805467                           1.396137
# 9997                 1.230329                           0.159247
# 9998                 0.200456                           0.294098
# 9999                 6.953205                          -1.394891
#
#       metadata_songs_artist_hotttnesss  metadata_songs_song_hotttnesss
# 0                             0.042065                        2.397801
# 1                             0.420843                        1.552509
# 2                            -2.960846                        0.000000
# 3                            -0.359450                        0.000000
# 4                            -0.537565                        0.000000
# ...                                ...                             ...
# 9995                         -2.960846                        0.000000
# 9996                          3.459743                        0.000000
# 9997                         -0.276075                       -0.899601
# 9998                         -0.054379                        3.681032
# 9999                         -0.582403                        0.000000
#
# [10000 rows x 24 columns]

# %% [markdown]
# ## Object

# %%
# drop all cols ending in id
id_cols_obj = [col for col in df_obj if col.endswith('id')]
df_obj = df_obj[[col for col in df_obj if not id_cols_obj.__contains__(col)]]

# %%
df_obj = df_obj.drop([
    'analysis_bars_confidence',
    'analysis_bars_start',
    'analysis_beats_confidence',
    'analysis_beats_start',
    'analysis_sections_confidence',
    'analysis_sections_start',
    'analysis_segments_confidence',
    'analysis_segments_loudness_max',
    'analysis_segments_loudness_max_time',
    'analysis_segments_loudness_start',
    'analysis_segments_pitches',
    'analysis_segments_start',
    'analysis_tatums_confidence',
    'analysis_tatums_start',
    'analysis_segments_timbre',
    'analysis_songs_audio_md5',
    'metadata_songs_artist_location',
    'metadata_artist_terms_freq',
    'metadata_artist_terms_weight',
    'metadata_similar_artists',
    'musicbrainz_artist_mbtags_count',
    'metadata_songs_analyzer_version',
    'metadata_songs_genre'], axis=1)

# %%
list(df_obj.columns)
# Out:
# ['metadata_artist_terms',
#  'metadata_songs_artist_name',
#  'metadata_songs_release',
#  'metadata_songs_title',
#  'musicbrainz_artist_mbtags']

# %%
df_obj['musicbrainz_artist_mbtags'] = ['|'.join(map(str, l)) for l in df_obj['musicbrainz_artist_mbtags']]

# %%
df_obj['metadata_artist_terms'] = ['|'.join(map(str, l)) for l in df_obj['metadata_artist_terms']]

# %%
df_obj
# Out:
#                                   metadata_artist_terms  \
# 0     b'chanson'|b'visual kei'|b'hip hop'|b'pop rock...
# 1     b'chanson'|b'dance pop'|b'pop rock'|b'soft roc...
# 2     b'early music'|b'celtic'|b'mediaeval'|b'folk'|...
# 3     b'post-hardcore'|b'doomcore'|b'metalcore'|b'sc...
# 4     b'orchestra'|b'musical theater'|b'british'|b'b...
# ...                                                 ...
# 9995  b'country gospel'|b'ccm'|b'country'|b'aor'|b'a...
# 9996  b'dance rock'|b'pop rock'|b'british pop'|b'bal...
# 9997  b'hard rock'|b'modern rock'|b'glam metal'|b'ro...
# 9998  b'frevo'|b'samba'|b'banda'|b'rockabilly'|b'bos...
# 9999     b'fusion'|b'ethnic'|b'ethnic and world fusion'
#
#      metadata_songs_artist_name  \
# 0                       Raphaël
# 1                 Julie Zenatti
# 2         The Baltimore Consort
# 3                  I Hate Sally
# 4        Orlando Pops Orchestra
# ...                         ...
# 9995                 Brent Lamb
# 9996                         U2
# 9997                        ZO2
# 9998                      Eddie
# 9999             Vincent Bruley
#
#                                  metadata_songs_release  \
# 0               Je Sais Que La Terre Est Plate (Deluxe)
# 1                                            Comme Vous
# 2       Watkins Ale -  Music of the English Renaissance
# 3                                      Don't Worry Lady
# 4                         Easy Listening: Cartoon Songs
# ...                                                 ...
# 9995                        Reflections Of A Simple Man
# 9996                                            October
# 9997                                 Ain't It Beautiful
# 9998  Brazil Classics 7: What's Happening in Pernamb...
# 9999                                 Oxygène 5: Le Vent
#
#                        metadata_songs_title  \
# 0            Je Sais Que La Terre Est Plate
# 1                                 On Efface
# 2                           Howells Delight
# 3                             Martha Served
# 4     Zip-A-Dee-Doo-Dah (Song of the South)
# ...                                     ...
# 9995                       One About Heaven
# 9996                                October
# 9997                            Comin' Home
# 9998                         Pode Me Chamar
# 9999                              Souffle 2
#
#                               musicbrainz_artist_mbtags
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 9995
# 9996  b'irish'|b'rock'|b'ireland'|b'irlandais'|b'cla...
# 9997
# 9998
# 9999
#
# [10000 rows x 5 columns]

# %%
list(df_id.columns)
# Out:
# ['analysis_songs_track_id',
#  'metadata_songs_artist_7digitalid',
#  'metadata_songs_artist_id',
#  'metadata_songs_artist_mbid',
#  'metadata_songs_artist_playmeid',
#  'metadata_songs_release_7digitalid',
#  'metadata_songs_song_id',
#  'metadata_songs_track_7digitalid']

# %%
df_id.head()
# Out:
#   analysis_songs_track_id  metadata_songs_artist_7digitalid  \
# 0      TRARRZU128F4253CA2                             16971
# 1      TRARRJL128F92DED0E                             92108
# 2      TRARRUZ128F9307C57                              1701
# 3      TRARRWA128F42A0195                             92184
# 4      TRARRPG12903CD1DE9                            278655
#
#   metadata_songs_artist_id            metadata_songs_artist_mbid  \
# 0       AREJXK41187B9A4ACC  c43bb0d6-94d7-410f-80fb-e5a243b18d23
# 1       AR2XRFQ1187FB417FE  a69cd724-2f57-4ed0-bfed-ba20401eb84c
# 2       ARODOO01187FB44F4A  60bd8a1c-c093-4849-8f28-08101ca059b1
# 3       ARJGW911187FB586CA  44b5b950-2ae2-403a-8c67-82d8fc72033d
# 4       AR9HQ6Y1187FB3C2CB  0e6524bd-6641-46a6-bce5-96f06c19aa46
#
#    metadata_songs_artist_playmeid  metadata_songs_release_7digitalid  \
# 0                            2676                             275907
# 1                            5772                             382807
# 2                           20540                             490659
# 3                              -1                             116616
# 4                              -1                             767122
#
#   metadata_songs_song_id  metadata_songs_track_7digitalid
# 0     SOGSMXL12A81C23D88                          3073568
# 1     SOMBCOW12AAF3B229F                          4249244
# 2     SOEYIHF12AB017B5F4                          5436063
# 3     SODJYEC12A8C13D757                          1199928
# 4     SOGSOUE12A58A76443                          8493899

# %%
df_m = pd.DataFrame()
for col in df_id:
    df_m[col] = df_id[col]
for col in df_num_cat:
    df_m[col] = df_num_cat[col]
for col in df_num:
    df_m[col] = df_num[col]
for col in df_obj:
    df_m[col] = df_obj[col]

# %%
df_m = df_m.drop([
    'metadata_songs_artist_7digitalid', 
    'metadata_songs_artist_mbid',
    'metadata_songs_release_7digitalid',
    'metadata_songs_artist_playmeid',
    'metadata_songs_track_7digitalid'], axis=1)

# %%
df_master = df[['user','song','count']].merge(df_m, left_on='song', right_on='metadata_songs_song_id')

# %%
df_master.shape
# Out:
# (772661, 27)

# %%
df_master.head()
# Out:
#                                        user                song  count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOWEZSI12A81C21CE6      1
# 1  833c530ecda3d99deb8395f70400aa3999783d91  SOWEZSI12A81C21CE6      2
# 2  d6c5bd2b570b4faf8964d7ed04f3392ff505d2be  SOWEZSI12A81C21CE6      1
# 3  724534729c9f5dc72a009269c2c225883e4775d2  SOWEZSI12A81C21CE6      1
# 4  ee7aa84c164038c963cfd02a7e52a5598aa470c3  SOWEZSI12A81C21CE6      2
#
#   analysis_songs_track_id metadata_songs_artist_id metadata_songs_song_id  \
# 0      TRAUCNU128F42671EB       AR2UQQ51187B9AC816     SOWEZSI12A81C21CE6
# 1      TRAUCNU128F42671EB       AR2UQQ51187B9AC816     SOWEZSI12A81C21CE6
# 2      TRAUCNU128F42671EB       AR2UQQ51187B9AC816     SOWEZSI12A81C21CE6
# 3      TRAUCNU128F42671EB       AR2UQQ51187B9AC816     SOWEZSI12A81C21CE6
# 4      TRAUCNU128F42671EB       AR2UQQ51187B9AC816     SOWEZSI12A81C21CE6
#
#    analysis_songs_key  analysis_songs_key_confidence  analysis_songs_mode  \
# 0                   5                          0.351                    0
# 1                   5                          0.351                    0
# 2                   5                          0.351                    0
# 3                   5                          0.351                    0
# 4                   5                          0.351                    0
#
#    analysis_songs_mode_confidence  ...  tempo_binned  analysis_songs_duration  \
# 0                           0.318  ...             8                -0.280898
# 1                           0.318  ...             8                -0.280898
# 2                           0.318  ...             8                -0.280898
# 3                           0.318  ...             8                -0.280898
# 4                           0.318  ...             8                -0.280898
#
#    metadata_songs_artist_familiarity  metadata_songs_artist_hotttnesss  \
# 0                           0.732042                          1.243373
# 1                           0.732042                          1.243373
# 2                           0.732042                          1.243373
# 3                           0.732042                          1.243373
# 4                           0.732042                          1.243373
#
#    metadata_songs_song_hotttnesss  \
# 0                         5.09644
# 1                         5.09644
# 2                         5.09644
# 3                         5.09644
# 4                         5.09644
#
#                                metadata_artist_terms  \
# 0  b'flamenco'|b'soundtrack'|b'folk'|b'spanish'|b...
# 1  b'flamenco'|b'soundtrack'|b'folk'|b'spanish'|b...
# 2  b'flamenco'|b'soundtrack'|b'folk'|b'spanish'|b...
# 3  b'flamenco'|b'soundtrack'|b'folk'|b'spanish'|b...
# 4  b'flamenco'|b'soundtrack'|b'folk'|b'spanish'|b...
#
#    metadata_songs_artist_name  metadata_songs_release  metadata_songs_title  \
# 0                 Gipsy Kings           Greatest Hits     Tu Quieres Volver
# 1                 Gipsy Kings           Greatest Hits     Tu Quieres Volver
# 2                 Gipsy Kings           Greatest Hits     Tu Quieres Volver
# 3                 Gipsy Kings           Greatest Hits     Tu Quieres Volver
# 4                 Gipsy Kings           Greatest Hits     Tu Quieres Volver
#
#          musicbrainz_artist_mbtags
# 0  b'classic pop and rock'|b'folk'
# 1  b'classic pop and rock'|b'folk'
# 2  b'classic pop and rock'|b'folk'
# 3  b'classic pop and rock'|b'folk'
# 4  b'classic pop and rock'|b'folk'
#
# [5 rows x 27 columns]

# %%
df_master.to_pickle(reldir + 'final/combined.csv', compression='zip')
df_m.to_pickle(reldir + 'final/songdata.csv', compression='zip')

# %%
pd.Series(years_enc).to_pickle(reldir + 'final/years_enc.csv', compression='zip')
pd.Series(tempo_enc).to_pickle(reldir + 'final/tempo_enc.csv', compression='zip')
