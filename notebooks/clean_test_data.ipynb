# %%
import pandas as pd

# %%
reldir = '../datasets/'

# %%
df_test = pd.read_csv(reldir + 'kaggle_visible_evaluation_triplets.txt', sep='\t', header=None, names=['user','song','count'])

# %%
df_test.head()
# Out:
#                                        user                song  count
# 0  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOBONKR12A58A7A7E0      1
# 1  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3      1
# 2  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOFLJQZ12A6D4FADA6      1
# 3  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOHTKMO12AB01843B0      1
# 4  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SODQZCY12A6D4F9D11      1

# %%
df_train = pd.read_pickle(reldir + 'clean_df.csv', compression='zip')

# %%
df_train.head()
# Out:
#                                        user                song  count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOWEZSI12A81C21CE6      1
# 1  833c530ecda3d99deb8395f70400aa3999783d91  SOWEZSI12A81C21CE6      2
# 2  d6c5bd2b570b4faf8964d7ed04f3392ff505d2be  SOWEZSI12A81C21CE6      1
# 3  724534729c9f5dc72a009269c2c225883e4775d2  SOWEZSI12A81C21CE6      1
# 4  ee7aa84c164038c963cfd02a7e52a5598aa470c3  SOWEZSI12A81C21CE6      2
#
#                      Song - Artist
# 0  Tu Quieres Volver - Gipsy Kings
# 1  Tu Quieres Volver - Gipsy Kings
# 2  Tu Quieres Volver - Gipsy Kings
# 3  Tu Quieres Volver - Gipsy Kings
# 4  Tu Quieres Volver - Gipsy Kings

# %%
uusers_train = df_train['user'].unique()
usongs_train = df_train['song'].unique()
uusers_test = df_test['user'].unique()
usongs_test = df_test['song'].unique()

# %%
cusers = [user for user in uusers_test if uusers_train.__contains__(user)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-d87f6dd8ae89> in <module>
#       1 cusers = [user for user in uusers_test if uusers_train.__contains__(user)]
# ----> 2 csongs = [song for song in usongs_test if usongs_train.__contains(song)]
#
# <ipython-input-10-d87f6dd8ae89> in <listcomp>(.0)
#       1 cusers = [user for user in uusers_test if uusers_train.__contains__(user)]
# ----> 2 csongs = [song for song in usongs_test if usongs_train.__contains(song)]
#
# AttributeError: 'numpy.ndarray' object has no attribute '__contains'

# %%
len(cusers)
# Out:
# 0

# %%
csongs = [song for song in usongs_test if usongs_train.__contains__(song)]

# %%
len(csongs)
# Out:
# 1718

# %%
df_msd = pd.read_pickle(reldir + 'songdata.csv', compression='zip')

# %%
df_msd.head()
# Out:
#   analysis_songs_track_id metadata_songs_artist_id metadata_songs_song_id  \
# 0      TRARRZU128F4253CA2       AREJXK41187B9A4ACC     SOGSMXL12A81C23D88
# 1      TRARRJL128F92DED0E       AR2XRFQ1187FB417FE     SOMBCOW12AAF3B229F
# 2      TRARRUZ128F9307C57       ARODOO01187FB44F4A     SOEYIHF12AB017B5F4
# 3      TRARRWA128F42A0195       ARJGW911187FB586CA     SODJYEC12A8C13D757
# 4      TRARRPG12903CD1DE9       AR9HQ6Y1187FB3C2CB     SOGSOUE12A58A76443
#
#    analysis_songs_key  analysis_songs_key_confidence  analysis_songs_mode  \
# 0                   0                          0.591                    1
# 1                   1                          0.429                    0
# 2                   3                          0.000                    1
# 3                   7                          0.380                    1
# 4                  10                          0.551                    1
#
#    analysis_songs_mode_confidence  analysis_songs_tempo  \
# ...
